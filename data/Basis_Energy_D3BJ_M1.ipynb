# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Read Data
data_900_raw = pd.read_csv('model1_csv/model1_data_900.csv')
data_900 = data_900_raw.round(2)
data_900
# Out:
#               Basis    EZPE       U       H       G       E
# 0          6-31G(d) -795.90 -795.88 -795.88 -795.94 -796.14
# 1         6-31G(dp) -795.93 -795.91 -795.91 -795.97 -796.21
# 2        6-31+G(dp) -795.97 -795.95 -795.95 -796.01 -796.21
# 3        6-311G(dp) -796.13 -796.11 -796.11 -796.18 -796.37
# 4      6-311++G(dp) -796.15 -796.13 -796.13 -796.20 -796.39
# 5    6-311G(2df2pd) -796.18 -796.16 -796.16 -796.23 -796.42
# 6  6-311++G(2df2pd) -796.20 -796.18 -796.18 -796.24 -796.44

# %%
#Data
basis_set = data_900.Basis
EZPE = data_900.EZPE
U = data_900.U
H = data_900.H
G = data_900.G
E = data_900.E

#Aesthetics
fig = plt.figure()
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans'}
w=0.1

bar1 = np.arange(len(basis_set))
plt.barh(bar1, EZPE, w, color='#f94144ff', align='center', label='E+ZPE')

bar2 = bar2 = [i-w for i in bar1]
plt.barh(bar2, U, w, color='#45cb34ff', align='center', label='U')

bar3 = bar3 = [i-2*w for i in bar1]
plt.barh(bar3, H, w, color='#ffca4cff', align='center', label='H')

bar4 = bar4 = [i-3*w for i in bar1]
plt.barh(bar4, G, w, color='#28b4f1ff', align='center', label='G')

bar5 = bar5 = [i-4*w for i in bar1]
plt.barh(bar5, E, w, color='#f8961eff', align='center', label='E')

plt.legend(prop={'size': 7.5})

#Value Labels
def addlabels(x,y,v):
    for i in range(len(x)):
        plt.text(y[i]-0.098, i-v,y[i], ha="right", va="bottom")
        
#addlabels(bar1, EZPE, 0.1)
#addlabels(bar2, U, 0.1)
#addlabels(bar3, H, 0.1)
#addlabels(bar4, G, 0.1)
#addlabels(bar5, E, 0.1)
        
#Axes        
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_xlim([-795.5,-796.5])
plt.title('Energy Calculations (Hartree) Compared to Basis Set for Model 1 Isomer 900', font)
plt.ylabel('Basis Set', font)
plt.xlabel('Hartree', font)
plt.yticks(np.arange(7), ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1_900.png', bbox_inches='tight', dpi=300)
plt.show()
