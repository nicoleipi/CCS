# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import csv
import math

# %%
# declare variables
num_files = 16
num_rows = 7
num_columns = 2
#kcal_conv = 627.5095 #kcal/mol per 1 hartree
rt = 298.15*(0.001987/627.5095) #kcal/mol

# declare arrays
raw_data = np.zeros((num_files, num_rows, num_columns))
#print(raw_data)
input_filename = []

directory = r'B3LYP_model1/csv/'
file_id = 0
for file in os.listdir(directory):
    full_path = os.path.abspath(directory)
    real_file = full_path + "\\" + file
    input_filename.append(file)

    results = []

    with open(real_file) as csvfile:
        reader = csv.reader(csvfile, delimiter=',', quotechar='|') 
        row_id = 0
        for row in reader:
            if (row_id > 0):
                raw_data [file_id][row_id-1][0] = row[4]
                raw_data [file_id][row_id-1][1] = row[5]
            row_id = row_id + 1
    file_id = file_id + 1
#print(input_filename)
#print(raw_data)

# %%
def eq_frac(input_file, input_row, input_column):
    #print(-raw_data[input_file][input_row][input_column]/rt)
    numerator = -raw_data[input_file][input_row][input_column]/rt
    denominator = 0
    for i in range (0, 16):
        denominator = denominator + np.exp((-raw_data[i][input_row][input_column]/rt)-numerator)
    return(1.0/denominator)

# %%
raw_output = np.zeros((num_files, num_rows, num_columns))
for file_id in range (0, 16):
    for row_id in range (0, 7):
        raw_output [file_id][row_id][0] = eq_frac(file_id, row_id, 0)
        raw_output [file_id][row_id][1] = eq_frac(file_id, row_id, 1)

for file_id in range (0,16):
    print(input_filename[file_id])
    print(raw_output[file_id])
    print("")
    pd.DataFrame(raw_output[file_id]).to_csv('B3LYP_model1/calc/%s' % input_filename[file_id])
# Out:
# B3LYP_model1_data_118.csv
# [[0.35651494 0.48083373]
#  [0.39823362 0.49736155]
#  [0.1877801  0.25327479]
#  [0.1295687  0.16336751]
#  [0.16941984 0.22546795]
#  [0.24326255 0.39026367]
#  [0.39266172 0.60532272]]
#
# B3LYP_model1_data_150.csv
# [[4.41350187e-04 1.13760815e-05]
#  [3.64921345e-04 1.03023929e-05]
#  [2.96955301e-03 9.98277803e-05]
#  [9.03545575e-04 3.02095646e-05]
#  [5.60578190e-03 1.86829192e-04]
#  [2.62452904e-03 6.04920643e-05]
#  [7.77290288e-03 2.06272040e-04]]
#
# B3LYP_model1_data_273.csv
# [[1.84356531e-05 1.17576001e-06]
#  [1.94893765e-05 1.22431752e-06]
#  [6.22438676e-05 5.47109755e-06]
#  [1.92830535e-05 1.45941811e-06]
#  [7.50680900e-05 6.68940938e-06]
#  [7.06350725e-05 6.29860684e-06]
#  [2.36044539e-04 2.30206423e-05]]
#
# B3LYP_model1_data_295.csv
# [[1.51254468e-04 5.08282703e-06]
#  [1.26125901e-04 4.52766735e-06]
#  [5.81738881e-04 2.91674231e-05]
#  [2.31159016e-04 8.45860047e-06]
#  [8.57096478e-04 4.64204233e-05]
#  [3.82599346e-04 1.54579950e-05]
#  [8.90948685e-04 4.50240853e-05]]
#
# B3LYP_model1_data_338.csv
# [[0.36530707 0.2329693 ]
#  [0.34225972 0.22262138]
#  [0.42403437 0.38850088]
#  [0.49531218 0.35274312]
#  [0.4107114  0.41058896]
#  [0.39851275 0.24353393]
#  [0.24378773 0.18657969]]
#
# B3LYP_model1_data_340.csv
# [[3.22854192e-05 8.41713795e-06]
#  [2.82659242e-05 7.73086442e-06]
#  [8.99874134e-05 1.97499756e-05]
#  [3.41651925e-05 8.70031366e-06]
#  [1.62138528e-04 4.08450368e-05]
#  [1.19830632e-04 2.36785540e-05]
#  [4.18217330e-04 8.74545204e-05]]
#
# B3LYP_model1_data_422.csv
# [[1.62152722e-06 2.25323718e-08]
#  [1.28783323e-06 2.34977517e-08]
#  [1.89051342e-05 2.91268214e-07]
#  [3.75364092e-06 6.70588788e-08]
#  [3.75496243e-05 5.98240381e-07]
#  [2.21464458e-05 2.08674050e-07]
#  [7.04882798e-05 9.27483391e-07]]
#
# B3LYP_model1_data_455.csv
# [[1.82068987e-10 9.88388904e-12]
#  [1.73681654e-10 1.04171139e-11]
#  [3.68151682e-10 2.30421971e-11]
#  [2.82708474e-10 2.12474420e-11]
#  [9.00897878e-10 5.65622965e-11]
#  [9.94724579e-10 5.94726535e-11]
#  [2.55348136e-09 1.35856876e-10]]
#
# B3LYP_model1_data_490.csv
# [[1.30801790e-05 2.72859172e-06]
#  [1.10232564e-05 2.33591576e-06]
#  [4.10063094e-05 7.50248112e-06]
#  [2.17118824e-05 5.00715595e-06]
#  [5.59205215e-05 1.01711412e-05]
#  [3.39382979e-05 8.25441527e-06]
#  [4.79370688e-05 8.74769819e-06]]
#
# B3LYP_model1_data_591.csv
# [[0.0051416  0.00053696]
#  [0.00484792 0.00048752]
#  [0.02370175 0.00382209]
#  [0.0075398  0.0008465 ]
#  [0.03458931 0.00603223]
#  [0.01335471 0.00148342]
#  [0.04862606 0.00739631]]
#
# B3LYP_model1_data_599.csv
# [[2.81778003e-08 1.01048436e-08]
#  [2.44097705e-08 8.64789112e-09]
#  [4.78404695e-08 1.82867300e-08]
#  [2.58179941e-08 9.96495631e-09]
#  [6.58652124e-08 2.32254376e-08]
#  [3.92603970e-08 1.32309048e-08]
#  [7.96638357e-08 2.22729400e-08]]
#
# B3LYP_model1_data_609.csv
# [[2.78265512e-07 9.63041316e-09]
#  [2.49365560e-07 9.33123841e-09]
#  [1.23083896e-06 7.64434406e-08]
#  [5.00615522e-07 2.03266333e-08]
#  [2.22241789e-06 1.30456657e-07]
#  [5.94145765e-07 3.45945033e-08]
#  [1.93975214e-06 1.08655546e-07]]
#
# B3LYP_model1_data_640.csv
# [[0.0012933  0.00023367]
#  [0.00124422 0.00023204]
#  [0.00360092 0.00057945]
#  [0.00173141 0.00028514]
#  [0.00513943 0.0007978 ]
#  [0.00332732 0.00052125]
#  [0.00749795 0.00114581]]
#
# B3LYP_model1_data_683.csv
# [[0.22608477 0.27985127]
#  [0.21070214 0.27416109]
#  [0.26298702 0.33013206]
#  [0.31913381 0.47513252]
#  [0.24938465 0.3214044 ]
#  [0.2724563  0.35059411]
#  [0.14370252 0.15812846]]
#
# B3LYP_model1_data_801.csv
# [[4.14405014e-07 1.30062219e-08]
#  [4.43695065e-07 1.40906523e-08]
#  [2.90893064e-06 1.10492658e-07]
#  [5.93071017e-07 1.77663230e-08]
#  [5.71687964e-06 2.12135378e-07]
#  [3.11757123e-06 9.17755212e-08]
#  [1.40745394e-05 5.35478939e-07]]
#
# B3LYP_model1_data_900.csv
# [[0.04499959 0.00554623]
#  [0.04216055 0.00511024]
#  [0.09412822 0.02352851]
#  [0.04549937 0.00757126]
#  [0.12395381 0.03541675]
#  [0.06582893 0.01348909]
#  [0.15427139 0.0410549 ]]
