# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# B3LYP Gibb's Free Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model4/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model4/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([95,98])
plt.title('Model 1 Relative Populations (B3LYP) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/b_plots/g_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# B3LYP Electronic Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model4/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model4/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([98,100])
plt.title('Model 1 Relative Populations (B3LYP) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/b_plots/e_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# B3LYP-D3(BJ) Gibb's Free Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model4/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model4/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP-D3(BJ)) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/d_plots/g_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-78144ccf21d9> in <module>
#       8
#       9 directory = r'D3BJ_model4/useful_calc'
# ---> 10 for file in os.listdir(directory):
#      11     #print(file)
#      12     filename = os.path.splitext(file)[0]
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D3BJ_model4/useful_calc'

# %% [markdown]
# B3LYP-D3(BJ) Electronic Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model4/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model4/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP-D3(BJ)) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/d_plots/e_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()
