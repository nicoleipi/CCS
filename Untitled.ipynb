# %%
import pandas as pd
import matplotlib.pyplot as plt
data_683 = pd.read_csv('model1_data_683.csv')
data_683
# Out:
#           Basis Set       E+ZPE           U           H           G  \
# 0        6-31+G(dp) -795.969921 -795.954341 -795.953397 -796.015039
# 1    6-311G(2df2pd) -796.183387 -796.167843 -796.166899 -796.228479
# 2         6-31G(dp) -795.932501 -795.917042 -795.916098 -795.977393
# 3  6-311++G(2df2pd) -796.200464 -796.184856 -796.183912 -796.245611
# 4        6-311G(dp) -796.132907 -796.117424 -796.116480 -796.177798
# 5      6-311++G(dp) -796.152329 -796.136724 -796.135780 -796.197454
#
#             E
# 0 -796.215843
# 1 -796.429105
# 2 -796.179218
# 3 -796.445914
# 4 -796.378619
# 5 -796.397555

# %%
plt.figure(figsize=(10,7))
plt.plot(data_683['Basis Set'],data_683['E+ZPE'],color='red',label="E+ZPE")
plt.xlabel("Basis Set")
plt.xlim((-0.5,3.5))
plt.ylabel("I [mA]")
plt.legend(loc="upper left")
plt.title("I-V curves for LEDs")
plt.savefig("LED_curves.pdf")
plt.show()
plt.show()
