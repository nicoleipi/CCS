# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# Model 1 B3LYP Gibb's Free Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model1/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model1/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/b_plots/g_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/b_plots/g_re_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Model 1 B3LYP Electronic Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model1/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model1/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/b_plots/e_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/b_plots/e_re_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Model 1 B3LYP-D3(BJ) Gibb's Free Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model1/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model1/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP-D3(BJ)) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/d_plots/g_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP-D3(BJ)) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/d_plots/g_re_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Model 1 B3LYP-D3(BJ) Electronic Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model1/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model1/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP-D3(BJ)) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/d_plots/e_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP-D3(BJ)) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/d_plots/e_re_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Model 4 B3LYP Gibb's Free Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model4/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model4/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([96,100])
plt.title('Model 4 Relative Populations (B3LYP) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/b_plots/g_model4.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model4/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model4/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([96,100])
plt.title('Model 4 Relative Populations (B3LYP) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/b_plots/g_re_model4.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Model 4 B3LYP Electronic Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model4/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model4/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([96,100])
plt.title('Model 4 Relative Populations (B3LYP) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/b_plots/e_model4.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model4/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model4/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([96,100])
plt.title('Model 4 Relative Populations (B3LYP) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/b_plots/e_re_model4.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Model 4 B3LYP-D3(BJ) Gibb's Free Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model4/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model4/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([96,100])
plt.title('Model 4 Relative Populations (B3LYP-D3(BJ)) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/d_plots/g_model4.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model4/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model4/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G

    plt.plot(basis, G, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([96,100])
plt.title('Model 4 Relative Populations (B3LYP-D3(BJ)) Gibb\'s Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/d_plots/g_re_model4.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Model 4 B3LYP-D3(BJ) Electronic Energy

# %%
#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model4/useful_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model4/useful_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([96,100])
plt.title('Model 4 Relative Populations (B3LYP-D3(BJ)) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-31+G(d,p)', '6-311G(d,p)', '6-311++G(d,p)', '6-311G(2df,2pd)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/d_plots/e_model4.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model4/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model4/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    E = data.E

    plt.plot(basis, E, label=isomer[3], marker='o')

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([96,100])
plt.title('Model 4 Relative Populations (B3LYP-D3(BJ)) Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model4/d_plots/e_re_model4.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Comparison of Basis Sets

# %%
#Aesthetics
#mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, G, marker='o', color="c")
    plt.plot(basis, E, marker='o', color="c")

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP)', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/b_plots/basis_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
#mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'D3BJ_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, G, marker='o', color="c")
    plt.plot(basis, E, marker='o', color="c")

plt.legend(loc = 'best', ncol = 5)
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations (B3LYP-D3(BJ))', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/d_plots/basis_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Comparison of Energies

# %%
#Aesthetics
#mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G

    plt.plot(basis, G, marker='o', color="darkorange")

directory = r'D3BJ_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, G, marker='o', color="darkorange")
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations Gibbs Free Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/b_plots/genergy_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()

#Aesthetics
#mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["c", "seagreen", "cornflowerblue", "darkorange", "goldenrod"]) 
fig = plt.figure(figsize=(13, 6))
fig.patch.set_facecolor('white')

#Plotting
font = {'fontname':'DejaVu Sans',}

directory = r'B3LYP_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('B3LYP_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, E, marker='o', color="darkorange")

directory = r'D3BJ_model1/reformatted_calc'
for file in os.listdir(directory):
    #print(file)
    filename = os.path.splitext(file)[0]
    #print(filename)

    isomer = filename.split("_",4)
    
    #Read Data
    data_raw = pd.read_csv('D3BJ_model1/reformatted_calc/%s' % file)
    xdata = data_raw*100
    data = xdata.round(2)
    #print(data)
    
    #Data
    basis = data.basis_set
    G = data.G
    E = data.E

    plt.plot(basis, E, marker='o', color="darkorange")
 
#Axes
ax = plt.gca()
ax.set_facecolor('#ffffff')
ax.set_ylim([0,100])
plt.title('Model 1 Relative Populations Electronic Energy', font)
plt.xlabel('Basis Set', font, fontweight='bold')
plt.ylabel('Probablility (%)', font, fontweight='bold')
plt.xticks([0, 100, 200, 300, 400, 500, 600], ['6-31G(d)', '6-31G(d,p)', '6-311G(d,p)', '6-311G(2df,2pd)', '6-31+G(d,p)', '6-311++G(d,p)', '6-311++G(2df,2pd)'])

#Show
plt.savefig('model1/b_plots/eenergy_model1.png' % basis[1], bbox_inches='tight', dpi=300)
plt.show()
# Out:
#   File "<ipython-input-18-bc94c98ded7b>", line 87
#     G = data.
#              ^
# SyntaxError: invalid syntax
